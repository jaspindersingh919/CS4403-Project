# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
# %matplotlib inline

# %%
pd.reset_option('all')
# Out:
# /tmp/ipykernel_1241/2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# /tmp/ipykernel_1241/2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataset into pandas DataFrame
df = pd.read_csv("/content/drive/MyDrive/data/Darknet.CSV")
# Out:
# /tmp/ipykernel_1241/854109217.py:2: DtypeWarning: Columns (40,41,43,46,123,124) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/data/Darknet.CSV")

# %%
df
# Out:
#                                            Flow ID          Src IP  Src Port  \
# 0          10.152.152.11-216.58.220.99-57158-443-6   10.152.152.11     57158
# 1          10.152.152.11-216.58.220.99-57159-443-6   10.152.152.11     57159
# 2          10.152.152.11-216.58.220.99-57160-443-6   10.152.152.11     57160
# 3         10.152.152.11-74.125.136.120-49134-443-6   10.152.152.11     49134
# 4       10.152.152.11-173.194.65.127-34697-19305-6   10.152.152.11     34697
# ...                                            ...             ...       ...
# 141526        10.8.8.246-224.0.0.252-55219-5355-17      10.8.8.246     55219
# 141527        10.8.8.246-224.0.0.252-64207-5355-17      10.8.8.246     64207
# 141528        10.8.8.246-224.0.0.252-61115-5355-17      10.8.8.246     61115
# 141529        10.8.8.246-224.0.0.252-64790-5355-17      10.8.8.246     64790
# 141530    80.239.235.110-10.8.8.246-11666-60245-17  80.239.235.110     11666
#
#                 Dst IP  Dst Port  Protocol               Timestamp  \
# 0        216.58.220.99       443         6  24/07/2015 04:09:48 PM
# 1        216.58.220.99       443         6  24/07/2015 04:09:48 PM
# 2        216.58.220.99       443         6  24/07/2015 04:09:48 PM
# 3       74.125.136.120       443         6  24/07/2015 04:09:48 PM
# 4       173.194.65.127     19305         6  24/07/2015 04:09:45 PM
# ...                ...       ...       ...                     ...
# 141526     224.0.0.252      5355        17  22/05/2015 01:55:03 PM
# 141527     224.0.0.252      5355        17  22/05/2015 02:09:05 PM
# 141528     224.0.0.252      5355        17  22/05/2015 02:19:31 PM
# 141529     224.0.0.252      5355        17  22/05/2015 02:29:55 PM
# 141530      10.8.8.246     60245        17  22/05/2015 02:31:23 PM
#
#         Flow Duration  Total Fwd Packet  Total Bwd packets  ...  Unnamed: 115  \
# 0                 229                 1                  1  ...           NaN
# 1                 407                 1                  1  ...           NaN
# 2                 431                 1                  1  ...           NaN
# 3                 359                 1                  1  ...           NaN
# 4            10778451               591                400  ...           NaN
# ...               ...               ...                ...  ...           ...
# 141526         411806                 2                  0  ...           NaN
# 141527         411574                 2                  0  ...           NaN
# 141528         422299                 2                  0  ...           NaN
# 141529         411855                 2                  0  ...           NaN
# 141530      119990044              5995               6000  ...           NaN
#
#         Unnamed: 116  Unnamed: 117  Unnamed: 118  Unnamed: 119  Unnamed: 120  \
# 0                NaN           NaN           NaN           NaN           NaN
# 1                NaN           NaN           NaN           NaN           NaN
# 2                NaN           NaN           NaN           NaN           NaN
# 3                NaN           NaN           NaN           NaN           NaN
# 4                NaN           NaN           NaN           NaN           NaN
# ...              ...           ...           ...           ...           ...
# 141526           NaN           NaN           NaN           NaN           NaN
# 141527           NaN           NaN           NaN           NaN           NaN
# 141528           NaN           NaN           NaN           NaN           NaN
# 141529           NaN           NaN           NaN           NaN           NaN
# 141530           NaN           NaN           NaN           NaN           NaN
#
#         Unnamed: 121  Unnamed: 122  Unnamed: 123  Unnamed: 124
# 0                NaN           NaN           NaN           NaN
# 1                NaN           NaN           NaN           NaN
# 2                NaN           NaN           NaN           NaN
# 3                NaN           NaN           NaN           NaN
# 4                NaN           NaN           NaN           NaN
# ...              ...           ...           ...           ...
# 141526           NaN           NaN           NaN           NaN
# 141527           NaN           NaN           NaN           NaN
# 141528           NaN           NaN           NaN           NaN
# 141529           NaN           NaN           NaN           NaN
# 141530           NaN           NaN           NaN           NaN
#
# [141531 rows x 125 columns]

# %%
print(df['Label'].value_counts())

print("\n-----------------\n")

print(df['Label.1'].value_counts())
# Out:
# Label
# Non-Tor        93356
# NonVPN         23863
# VPN            22919
# Tor             1392
# 5494.505495        1
# Name: count, dtype: int64
#
# -----------------
#
# Label.1
# P2P                48520
# Browsing           32808
# Audio-Streaming    16580
# Chat               11478
# File-Transfer      11098
# Video-Streaming     9486
# Email               6145
# VOIP                3566
# AUDIO-STREAMING     1484
# Video-streaming      281
# File-transfer         84
# 0                      1
# Name: count, dtype: int64

# %%
# Removing corrupted row in Label
df = df[df['Label'].isin(['Non-Tor','NonVPN','VPN','Tor'])]

# Standardizing Label.1 values
df['Label.1'] = df['Label.1'].replace({
    'AUDIO-STREAMING':'Audio-Streaming',
    'Video-streaming':'Video-Streaming',
    'File-transfer':'File-Transfer'
})

# Removing invalid Label.1 row
df = df[df['Label.1'] != '0']

print(df['Label'].value_counts())

print("\n-----------------\n")

print(df['Label.1'].value_counts())
# Out:
# Label
# Non-Tor    93356
# NonVPN     23863
# VPN        22919
# Tor         1392
# Name: count, dtype: int64
#
# -----------------
#
# Label.1
# P2P                48520
# Browsing           32808
# Audio-Streaming    18064
# Chat               11478
# File-Transfer      11182
# Video-Streaming     9767
# Email               6145
# VOIP                3566
# Name: count, dtype: int64

# %%
df['Label'].value_counts().plot(kind='bar')

plt.title('Traffic Type Distribution')
plt.xlabel('Traffic Type')
plt.ylabel('Count')

plt.show()
